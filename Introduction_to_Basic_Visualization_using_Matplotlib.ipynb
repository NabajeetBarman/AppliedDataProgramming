# %% [markdown]
# <a href="https://colab.research.google.com/github/NabajeetBarman/AppliedDataProgramming/blob/main/Introduction_to_Basic_Visualization_using_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction to Basic Visualization using Matplotlib
# #####################################################################################
#
# Parts of this module is borrowed from the official [Matplotlib v3.4.3](https://matplotlib.org/) website.
#
# Copyright@ *Nabajeet Barman* (nabajeetbarman4@gmail.com)
#
# #####################################################################################
#
# ## Topics Covered:
#
# > * Introduction to Matplotlib
# > * Plotting arrays with Matplotlib
#   * Customizing plot properties
# > * Creating a simple plot
# > * Example Plots
#   * Stacked bar chart
#   * Box plots with custom fill colors
#   * Creating a timeline with lines, dates, and text
#
# Note: We will only cover the basics of Matplotlib to help create the required plots for the Coursework. More visusalization related topics will be covered in Data Analytics and Visualization module.

# %% [markdown]
# # Matplotlib Introduction
#
# Matplotlib is a module that contains classes and functions for creating MATLABstyle graphics and plots with just a few lines of code
# * plots, histograms, power spectra, bar charts, errorcharts,scatterplots, etc.
# * http://matplotlib.org/gallery.html
#
#               **A picture is worth a thousand words.**
#
# >* Matplotlib tries to make easy things easy and hard things possible.
# >* Matplotlib was modeled on MATLAB.
# >* Matplotlib is a Python package for 2D plotting that generates production-quality graphs.
# >* It supports interactive and non-interactive plotting, and can save images in several output formats (PNG, PS, and others).
# >* It can use multiple window toolkits (GTK+, wxWidgets, Qt, and so on) and it provides a wide variety of plot types (lines, bars, pie charts, histograms, and many more).
# >* It is highly customizable, flexible, and easy to use.
#
#
#                 **NumPy has to be available to use Matplotlib.**
#
#
# The primary submodule we will use is `pyplot`, which is commonly aliased as `plt`.

# %% [markdown]
# Let us start with importing matplotlib and numpy

# %%
import matplotlib.pyplot as plt
# other way: from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Figure and Axis Objects
#
# A *figure object* can essentially be thought of as the ‘virtual page’ or ‘virtual piece of paper’ that defines the canvas on which the plot
# appears.
#
# The *axes object* is the set of axes (usually x and y) that the data are plotted on.

# %% [markdown]
# ## Parts of a Figure
#
# ![Anatomy of a Figure ](https://drive.google.com/uc?export=view&id=1yosukF1YlQTva3NTkWvD7pghrOKOyYuR)

# %% [markdown]
# Spines are the lines connecting the axis tick marks and noting the boundaries of the data area. They can be placed at arbitrary positions.
#
# ## Creating a simple plot
#
# **`pyplot.plot()` automatically creates both the figure and axis objects and plots the data onto them.**
#
# Hence, a simple way to create a plot is:

# %%
plt.plot([1,2,3,4,5]) # a simple plot
# if you are not using Colab, you need to use plt.show()
# you can use the magic command at start which is %matplotlib inline

# %%
# mentioning both x and y value
plt.plot([1, 2, 3, 4],[1, 4, 2, 3])

# %% [markdown]
# ### Declaring variables and using them as input to plot

# %%
x_val = [1, 2, 3, 4]
y_val = [1, 4, 2, 3]
plt.plot(x_val,y_val)  # Matplotlib plot.

# %% [markdown]
# ## Few properties you can use

# %%
# change the plot linewidth (one of the important properties)
plt.plot(x_val,y_val,linewidth=6)  # Matplotlib plot.

# %%
# change the color of the line
plt.plot(x_val,y_val,linewidth=6,color='r')  # Matplotlib plot.

# %% [markdown]
# Basic built in colors include:
#
# b: blue
# g: green
# r: red
# c: cyan
# m: magenta
# y: yellow
# k: black
# w: white
#
# Check here for the colors that are supported and their respective codes:
# https://matplotlib.org/2.0.2/api/colors_api.html

# %%
# change line style
plt.plot(x_val,y_val,linewidth=6,color='r',ls='--')  # Matplotlib plot.

# %% [markdown]
# Let us add some axis name and a title to the figure

# %%
x_val = [1, 2, 3, 4]
y_val = [1, 4, 2, 3]
plt.plot(x_val,y_val)  # Matplotlib plot.
plt.xlabel('Some x values')
plt.ylabel('Some y values')
plt.title('Some Title')
# Out:
# Text(0.5, 1.0, 'Some Title')

# %%
x_val = [1,2,3,4,5]
y_val = [1,4,6,3,9]
plt.plot(x_val,y_val,linewidth=6,color='r')
plt.xlabel('Some x values', fontsize=20)
plt.ylabel('Some y values', fontsize=20)
# assign the last command's output to suppress the text part below
y = plt.title('Some Title', fontsize=20)
# or alternatively, if you do not want to use y, use plt.show()
# using plt.show() does not result in the text part

# %% [markdown]
# ## Pyplot Subplots
#
# Another simple way of creating a figure with an axes is using `pyplot subplots`.
#
# We can then use `axes.plot` to draw some data on the axes:

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %% [markdown]
# **Discussion**: When to use `pyplot.plot()` versus `pyplot.figure()` and `figure.add_axes()`
#
# * Most plotting with only a single set of axes can be accomplished using the `pyplot.plot()` function.
# * For plots with multiple axes, or when detailed control of axes placement is required, then the `pyplot.figure()` and `figure.add_axes()` methods, or similar methods, are needed.

# %% [markdown]
# Getting References to the Current Figure and Axes
#
# * A reference to the current figure can always be obtained by using the `pyplot.gcf()` function.
# * * Example: `fig = plt.gcf()`
#
# * Likewise, a reference to the current axes is obtained using `pyplot.gca()`:
# * * Example: `ax = plt.gca()`

# %% [markdown]
# ### Creating a figure with no axis

# %%
fig = plt.figure()  # an empty figure with no Axes

# %% [markdown]
# ### Creating a figure with single axes

# %%
fig, ax = plt.subplots()  # a figure with a single Axes

# %% [markdown]
# ### Creating a figure with subplots with a 2x2 grid of axes

# %%
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %% [markdown]
# # Creating multiple subplots using ``plt.subplots``
#
# `.pyplot.subplots` creates a figure and a grid of subplots with a single call,
# while providing reasonable control over how the individual plots are created.
# For more advanced use cases you can use `.GridSpec` for a more general subplot
# layout or `.Figure.add_subplot` for adding subplots at arbitrary locations
# within the figure.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)
z = np.tan(x ** 2)

# %% [markdown]
# ## A figure with just one subplot
#
# ``subplots()`` without arguments returns a `.Figure` and a single
# `~.axes.Axes`.
#
# This is actually the simplest and recommended way of creating a single
# Figure and Axes.

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('A single plot')
# Out:
# Text(0.5, 1.0, 'A single plot')

# %% [markdown]
# ## Stacking subplots in one direction
#
# The first two optional arguments of `.pyplot.subplots` define the number of
# rows and columns of the subplot grid.
#
# When stacking in one direction only, the returned ``axs`` is a 1D numpy array
# containing the list of created Axes.

# %%
fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(x, y)
axs[1].plot(x, z)

# %%
# Other method
#plot 1:
plt.subplot(2, 1, 1)
plt.plot(x,y)
#plot 2:
plt.subplot(2, 1, 2)
plt.plot(x,z)
plt.show()

# %% [markdown]
# If you are creating just a few Axes, it's handy to unpack them immediately to
# dedicated variables for each Axes. That way, we can use ``ax1`` instead of
# the more verbose ``axs[0]``.

# %%
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
ax1.plot(x, y)
ax2.plot(x, z)

# %% [markdown]
# To obtain side-by-side subplots, pass parameters ``1, 2`` for one row and two
# columns.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x, y)
ax2.plot(x, z)

# %%
# Other method
#plot 1:
plt.subplot(1, 2, 1)
plt.plot(x,y)
#plot 2:
plt.subplot(1, 2, 2)
plt.plot(x,z)
plt.suptitle('Horizontally stacked subplots')
plt.show()

# %% [markdown]
# ## Modifying properties

# %%
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(15,8))
fig.tight_layout(pad=7.0) # for spacing
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x, y)
ax1.set_title('Subplot 1 - Sine Plot')
ax1.set(xlabel='X1-axis', ylabel='Y1-axis')
ax2.plot(x, z)
ax2.set_title('Subplot 2 - Cosine Plot')
ax2.set(xlabel='X2-axis', ylabel='Y2-axis')
# Out:
# [Text(564.6704545454544, 0.5, 'Y2-axis'), Text(0.5, 51.0, 'X2-axis')]

# %% [markdown]
# # Changing line property

# %%
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,15))
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x, y)
ax1.set_title('Subplot 1 - Sine Plot')
ax1.set(xlabel='X1-axis', ylabel='Y1-axis')
ax2.plot(x, z)
ax2.set_title('Subplot 2 - Cosine Plot')
ax2.set(xlabel='X2-axis', ylabel='Y2-axis')
ax2.xaxis.label.set_size(20)
ax2.yaxis.label.set_size(20)
ax2.title.set_size(20)
## to adjust spacing between subplots

# %%
# Other method
plt.figure(figsize=(16, 8))
#plot 1
plt.subplot(1, 2, 1)
plt.plot(x,y,linewidth=6,color='r')
plt.title('Subplot 1 - Sine Plot', fontsize=20)
plt.xlabel('X1-axis')
plt.ylabel('Y1-axis')
#plot 2:
plt.subplot(1, 2, 2)
plt.plot(x,z)
plt.title('Subplot 2 - Cosine Plot')
plt.xlabel('X2-axis')
plt.ylabel('Y2-axis')
# Main title
plt.suptitle('Horizontally stacked subplots')
plt.show()

# %% [markdown]
# ## Stacking subplots in two directions
#
# When stacking in two directions, the returned ``axs`` is a 2D NumPy array.
#
# If you have to set parameters for each subplot it's handy to iterate over
# all subplots in a 2D grid using ``for ax in axs.flat:``.

# %%
fig, axs = plt.subplots(2, 2)
axs[0, 0].plot(x, y)
axs[0, 0].set_title('Axis [0, 0]')
axs[0, 1].plot(x, y, 'tab:orange')
axs[0, 1].set_title('Axis [0, 1]')
axs[1, 0].plot(x, z, 'tab:green')
axs[1, 0].set_title('Axis [1, 0]')
axs[1, 1].plot(x, z, 'tab:red')
axs[1, 1].set_title('Axis [1, 1]')

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# You can use tuple-unpacking also in 2D to assign all subplots to dedicated
# variables:

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.suptitle('Sharing x per column, y per row')
ax1.plot(x, y)
ax2.plot(x, y**2, 'tab:orange')
ax3.plot(x, z, 'tab:green')
ax4.plot(x, z**2, 'tab:red')

for ax in fig.get_axes():
    ax.label_outer()

# %% [markdown]
# ### Plotting Multiple Lines on a Single Set of Axes
# * Multiple lines are plotted by repeated use of the `pyplot.plot()` function or `axes.plot()` method.
# * The color of each set of lines will automatically be different.

# %%
x = np.arange(0,100.5,0.5) # Generate x-axis values
y1 = 2.0*np.sqrt(x) # Calculate y1 values
y2 = 3.0*x**(1.0/3.0) # Calculate y2 values
plt.plot(x,y1) # Plot y1
plt.plot(x,y2) # Plot y2
plt.show() # Display plot to screen

# %% [markdown]
# ## Example of a Simple scatter plot
#
# The original code and description can be found [here](https://matplotlib.org/gallery/shapes_and_collections/scatter.html#sphx-glr-gallery-shapes-and-collections-scatter-py)

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
